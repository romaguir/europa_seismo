# %%
import instaseis
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal
from obspy.taup import TauPyModel
from europa_seismo.utils import phase_window
# %matplotlib inline

# %%
mars = TauPyModel('EH45Tcold')
db = instaseis.open_db('/home/romaguir/Documents/axisem_databases/Mars_EH45Tcold_5s_noatten_database')

# %%
source = instaseis.Source(longitude=0.0,latitude=0.0,depth_in_m=300.0,
    m_rr=3.98e13,m_pp=-3.98e18)
receiver = instaseis.Receiver(longitude=60.0,latitude=0.0)

# %%
arrs = mars.get_ray_paths(0.3,60.0,phase_list=['P'])
arrs.plot()
# Out:
# /home/romaguir/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: ObsPyDeprecationWarning: The plot() function is deprecated. Please use arrivals.plot_rays()
#   from ipykernel import kernelapp as app
